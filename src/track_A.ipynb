# %%
# %pip install -q numpy pandas scikit-learn
# %pip install numpy

# %%
import json
from typing import List, Dict
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel

from scipy.stats import pearsonr
from tqdm import tqdm
import math
import re
import requests
import os

# %%
def load_jsonl(path):
    items = []
    with open(path, "r", encoding="utf8") as f:
        for line in f:
            items.append(json.loads(line))
    return pd.DataFrame(items)

def load_jsonl_url(url: str) -> List[Dict]:
    resp = requests.get(url)
    resp.raise_for_status()
    return [json.loads(line) for line in resp.text.splitlines()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2801204891.py in <cell line: 0>()
#       6     return pd.DataFrame(items)
#       7
# ----> 8 def load_jsonl_url(url: str) -> List[Dict]:
#       9     resp = requests.get(url)
#      10     resp.raise_for_status()
#
# NameError: name 'List' is not defined

# %%
train_path = "/content/pred_eng_laptop.jsonl"
dev_path   = "/content/dev.jsonl"

train_df = load_jsonl(train_path)
dev_df   = load_jsonl(dev_path)

train_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1402067620.py in <cell line: 0>()
#       2 dev_path   = "/content/dev.jsonl"
#       3
# ----> 4 train_df = load_jsonl(train_path)
#       5 dev_df   = load_jsonl(dev_path)
#       6
#
# /tmp/ipython-input-2801204891.py in load_jsonl(path)
#       1 def load_jsonl(path):
#       2     items = []
# ----> 3     with open(path, "r", encoding="utf8") as f:
#       4         for line in f:
#       5             items.append(json.loads(line))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/pred_eng_laptop.jsonl'

# %%
print("Current directory:", os.getcwd())
# Out:
# Current directory: /content

# %%
print("\nFiles in /content/:")
# Out:
# Files in /content/:

# %%
# List all files in current directory
print("Files in current directory (/content/):")
for item in os.listdir('/content/'):
    print(f"  {item}")

# Search for your specific file
print("\nSearching for .jsonl files:")
# !find /content -name "*.jsonl" -type f

# Check if your specific file exists anywhere
print("\nSearching for pred_eng_laptop.jsonl:")
# !find / -name "pred_eng_laptop.jsonl" 2>/dev/null | head -5
# Out:
# Files in current directory (/content/):
#   .config
#   sample_data
#
# Searching for .jsonl files:
#
# Searching for pred_eng_laptop.jsonl:

# %%
# !ls /content/sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
import os

# Check if mount exists
if os.path.exists('/content/drive'):
    print("Unmounting existing drive...")
    # !fusermount -u /content/drive
    
# Wait a moment
import time
time.sleep(2)

# Now mount fresh
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3882847930.py in <cell line: 0>()
#      12 # Now mount fresh
#      13 from google.colab import drive
# ---> 14 drive.mount('/content/drive', force_remount=True)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# ...
